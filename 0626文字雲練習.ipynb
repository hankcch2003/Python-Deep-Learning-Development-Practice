# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = open('mayday1.txt', encoding='utf-8').read()
wc = WordCloud(background_color='white', max_words = 200)
wc.generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('wordcloud1.jpg')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = open('mayday1.txt', encoding='utf-8').read()
wc = WordCloud(background_color='white', max_words = 200, font_path='NotoSerifCJKtc-Black.otf')
wc.generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('wordcloud2.jpg')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = open('mayday1.txt', encoding='utf-8').read()
stopwords = {}.fromkeys(['yeah','oh','沒有','la'])
print(stopwords)
wc = WordCloud(background_color='white', max_words = 300, font_path='NotoSerifCJKtc-Black.otf', stopwords = stopwords)
wc.generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('wordcloud3.jpg')
# Out:
# {'yeah': None, 'oh': None, '沒有': None, 'la': None}

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text = open('data.txt', encoding='utf-8').read()
wc = WordCloud(background_color='white', max_words = 200, font_path='NotoSerifCJKtc-Black.otf')
wc.generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('wordcloud4.jpg')

# %%
import jieba
import collections
print('====如果有些詞彙沒列入語助詞stopWords.txt，請於txt檔案內新增====')
list1 = []
stopWords = []  # 不要的詞彙
remainderWords = []  # 去除不要的詞彙的清單
with open('stopWords.txt','r', encoding='utf-8') as file:
    for data in file:
        data = data.strip()  # 去除空白
        stopWords.append(data)
with open('data.txt','r', encoding='utf-8') as file:
    text = file.read()
    words = jieba.lcut(text)
print(words)
print('計算文字出現的頻率')
word_freq = collections.Counter(words)
print(word_freq)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\hankc\AppData\Local\Temp\jieba.cache
# ====如果有些詞彙沒列入語助詞stopWords.txt，請於txt檔案內新增====
# Loading model cost 0.727 seconds.
# Prefix dict has been built successfully.
# ...

# %%
word_freq = {'Python':100,'Data':80,'Visualization':60,'Machine':50,'Learning':40}
wc = WordCloud(background_color='white', font_path='NotoSerifCJKtc-Black.otf')
wc.generate_from_frequencies(word_freq)
plt.imshow(wc)
plt.axis('off')
plt.show()
wc.to_file('wordcloud5.jpg')
