# %%
# 匯入gymnasium套件，用於建構與操作強化學習環境
import gymnasium as gym

# 建立MuJoCo環境Ant-v4，並啟用人類可視畫面(render_mode='human')
env = gym.make("Ant-v4", render_mode='human')

# 重置環境，開始新的一局，獲得初始觀測值observation
observation = env.reset()

# 執行500個時間步(避免無窮迴圈)
for _ in range(500):
    # 顯示目前畫面
    env.render()

    # 從動作空間中隨機選取一個動作(代表agent的行為)
    action = env.action_space.sample()

    # 執行動作，傳回新的觀測值、獎勵、終止旗標、截斷旗標與其他資訊
    observation, reward, terminated, truncated, info = env.step(action)

    # 輸出目前狀態的詳細資訊(可用於觀察學習過程)
    print(observation, reward, terminated, truncated, info)

    # 若遊戲回合結束(成功或失敗)，則重置環境開始新的一局
    if terminated or truncated:
        observation, info = env.reset()

# 關閉環境並釋放資源
env.close()
# Out:
# c:\Users\hankc\anaconda3\Lib\site-packages\gymnasium\envs\registration.py:512: DeprecationWarning: WARN: The environment Ant-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# [ 8.59802458e-01  9.89631380e-01  1.00115164e-01  2.87586955e-02
#  -9.88919772e-02  1.70915092e-01  4.66446726e-01  8.87241674e-03
#  -3.80161898e-01  2.06660416e-01 -4.00399115e-01 -7.11056881e-02
#   4.26811972e-01  8.18542737e-02  1.11229089e-01  2.13958622e-01
#   5.14383801e-01 -2.77231561e-01 -5.03314206e-01  5.07649133e+00
#   1.20313808e+01 -1.75423536e+00 -9.15064617e+00  4.85035061e+00
# ...
