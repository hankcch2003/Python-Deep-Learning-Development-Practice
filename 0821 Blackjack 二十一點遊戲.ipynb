# %%
# pip install gymnasium
# pip install pygame

# 匯入gymnasium套件，為強化版的OpenAI Gym，用於建構與操作強化學習環境
import gymnasium as gym

# 建立經典遊戲環境Blackjack-v1，並啟用人類可視畫面(render_mode='human')
env = gym.make("Blackjack-v1", render_mode='human')

# 重置環境，開始新的一局，獲得初始觀測值observation
observation = env.reset()

# 執行100個時間步(避免無窮迴圈)
for _ in range(100):
    # 顯示目前畫面
    env.render()

    # 從動作空間中隨機選取一個動作(代表agent的行為)
    action = env.action_space.sample()

    # 執行動作，回傳新的觀測值、獎勵、終止旗標、截斷旗標與其他資訊
    observation, reward, terminated, truncated, info = env.step(action)

    # 印出目前狀態資訊(可用於觀察學習過程)
    print(observation, reward, terminated, truncated, info)

    # 若遊戲回合結束(成功或失敗)，則重置環境開始新的一局
    if terminated or truncated:
        observation, info = env.reset()

# 關閉環境並釋放資源
env.close()
# Out:
# (27, 8, 0) -1.0 True False {}
# (20, 10, 1) 0.0 False False {}
# (20, 10, 1) 1.0 True False {}
# (19, 1, 0) 0.0 False False {}
# (22, 1, 0) -1.0 True False {}
# (19, 3, 1) 1.0 True False {}
# (19, 2, 1) -1.0 True False {}
# (20, 9, 0) 1.0 True False {}
# (20, 7, 0) 1.0 True False {}
# (15, 10, 0) -1.0 True False {}
# (19, 8, 0) 0.0 False False {}
# (29, 8, 0) -1.0 True False {}
# (16, 10, 0) -1.0 True False {}
# (23, 10, 0) -1.0 True False {}
# (19, 2, 0) 0.0 False False {}
# (29, 2, 0) -1.0 True False {}
# (14, 8, 0) 0.0 False False {}
# (22, 8, 0) -1.0 True False {}
# (13, 10, 0) 0.0 False False {}
# (13, 10, 0) -1.0 True False {}
# (25, 5, 0) -1.0 True False {}
# (14, 10, 0) -1.0 True False {}
# (21, 4, 0) 0.0 False False {}
# (31, 4, 0) -1.0 True False {}
# (16, 10, 0) 1.0 True False {}
# (14, 7, 0) -1.0 True False {}
# (10, 6, 0) -1.0 True False {}
# (24, 7, 0) -1.0 True False {}
# (17, 4, 0) 0.0 False False {}
# (20, 4, 0) 0.0 False False {}
# (21, 4, 0) 0.0 False False {}
# (21, 4, 0) 1.0 True False {}
# (17, 3, 0) 0.0 True False {}
# (23, 8, 0) -1.0 True False {}
# (13, 9, 0) -1.0 True False {}
# (16, 10, 0) 1.0 True False {}
# (30, 10, 0) -1.0 True False {}
# (21, 6, 1) 1.0 True False {}
# (18, 6, 0) 0.0 True False {}
# (20, 10, 0) 0.0 True False {}
# (26, 7, 0) -1.0 True False {}
# (13, 8, 0) 0.0 False False {}
# (18, 8, 0) 0.0 False False {}
# (18, 8, 0) 0.0 True False {}
# (20, 10, 0) 1.0 True False {}
# (20, 5, 0) 0.0 False False {}
# (22, 5, 0) -1.0 True False {}
# (19, 6, 0) 0.0 False False {}
# (27, 6, 0) -1.0 True False {}
# (8, 8, 0) -1.0 True False {}
# (18, 7, 0) 0.0 False False {}
# (18, 7, 0) 1.0 True False {}
# (16, 10, 0) 0.0 False False {}
# (16, 10, 0) -1.0 True False {}
# (23, 2, 0) -1.0 True False {}
# (11, 3, 0) 0.0 False False {}
# (11, 3, 0) -1.0 True False {}
# (26, 5, 0) -1.0 True False {}
# (18, 10, 0) 0.0 False False {}
# (26, 10, 0) -1.0 True False {}
# (15, 10, 0) -1.0 True False {}
# (18, 9, 0) 0.0 False False {}
# (18, 9, 0) -1.0 True False {}
# (6, 4, 0) 1.0 True False {}
# (20, 6, 1) 1.0 True False {}
# (8, 2, 0) 0.0 False False {}
# (12, 2, 0) 0.0 False False {}
# (17, 2, 0) 0.0 False False {}
# (27, 2, 0) -1.0 True False {}
# (19, 9, 0) 0.0 False False {}
# (19, 9, 0) 1.0 True False {}
# (21, 4, 1) 1.0 True False {}
# (15, 10, 1) 1.0 True False {}
# (11, 4, 0) -1.0 True False {}
# (20, 10, 0) 1.0 True False {}
# (19, 1, 0) 0.0 False False {}
# (19, 1, 0) 1.0 True False {}
# (30, 10, 0) -1.0 True False {}
# (15, 7, 0) 1.0 True False {}
# (20, 10, 0) 0.0 False False {}
# (20, 10, 0) 0.0 True False {}
# (21, 2, 0) 0.0 False False {}
# (26, 2, 0) -1.0 True False {}
# (19, 10, 0) 0.0 False False {}
# (19, 10, 0) -1.0 True False {}
# (19, 9, 0) -1.0 True False {}
# (20, 10, 0) 0.0 False False {}
# (20, 10, 0) 1.0 True False {}
# (17, 3, 0) -1.0 True False {}
# (14, 10, 0) -1.0 True False {}
# (19, 10, 0) -1.0 True False {}
# (16, 1, 0) 0.0 False False {}
# (16, 1, 0) -1.0 True False {}
# (9, 10, 0) -1.0 True False {}
# (17, 3, 0) 1.0 True False {}
# (11, 5, 0) 1.0 True False {}
# (30, 7, 0) -1.0 True False {}
# (20, 2, 0) 0.0 False False {}
# (24, 2, 0) -1.0 True False {}
# (10, 9, 0) -1.0 True False {}
