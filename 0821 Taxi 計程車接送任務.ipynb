# %%
# pip install gymnasium
# pip install pygame

# 匯入gymnasium套件，為強化版的OpenAI Gym，用於建構與操作強化學習環境
import gymnasium as gym

# 建立經典離散環境Taxi-v3，並啟用人類可視畫面(render_mode='human')
env = gym.make("Taxi-v3", render_mode='human')

# 重置環境，開始新的一局，獲得初始觀測值observation
observation = env.reset()

# 執行100個時間步(避免無窮迴圈)
for _ in range(100):
    # 顯示目前畫面
    env.render()

    # 從動作空間中隨機選取一個動作(代表agent的行為)
    action = env.action_space.sample()

    # 執行動作，回傳新的觀測值、獎勵、終止旗標、截斷旗標與其他資訊
    observation, reward, terminated, truncated, info = env.step(action)

    # 印出目前狀態資訊
    print(observation, reward, terminated, truncated, info)

    # 若遊戲回合結束(成功或失敗)，則重置環境開始新的一局
    if terminated or truncated:
        observation, info = env.reset()

# 關閉環境並釋放資源
env.close()
# Out:
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 347 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 227 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 127 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 127 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 127 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 7 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 27 -10 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 27 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)}
# 7 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)}
# 107 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 127 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 127 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 127 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 107 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 207 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 407 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 307 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 0, 0, 0], dtype=int8)}
# 207 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 227 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 267 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 287 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 287 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 267 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 167 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 147 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 247 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 247 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 147 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 47 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)}
# 47 -1 False False {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)}
# 47 -10 False False {'prob': 1.0, 'action_mask': array([1, 0, 1, 0, 0, 0], dtype=int8)}
# 147 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 147 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 147 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 267 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 347 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 347 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 247 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 227 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 327 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 327 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 327 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 227 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 227 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 327 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 327 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 347 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 347 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 0, 1, 0, 0], dtype=int8)}
# 447 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 1, 0, 0], dtype=int8)}
# 447 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 1, 0, 0], dtype=int8)}
# 447 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 0, 1, 0, 0], dtype=int8)}
# 427 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 1, 0, 0, 0], dtype=int8)}
# 427 -10 False False {'prob': 1.0, 'action_mask': array([0, 1, 1, 0, 0, 0], dtype=int8)}
# 427 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 1, 0, 0, 0], dtype=int8)}
# 427 -1 False False {'prob': 1.0, 'action_mask': array([0, 1, 1, 0, 0, 0], dtype=int8)}
# 327 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 327 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 227 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 1, 0, 0], dtype=int8)}
# 207 -1 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
# 207 -10 False False {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)}
